# %%
# %%bash --bg
# roscore
# Out:
# Starting job # 0 in a separate thread.

# %%
# %%bash
# rosparam set use_sim_time true

# %%
# %%bash --bg
# rosrun gmapping slam_gmapping scan:=base_scan
# Out:
# Starting job # 2 in a separate thread.

# %%
# %%bash
# rosbag play --clock basic_localization_stage.bag
# Out:
# [ INFO] [1519297738.773389006]: Opening basic_localization_stage.bag
#
# Waiting 0.2 seconds after advertising topics... done.
#
# Hit space to toggle paused, or 's' to step.
#  [RUNNING]  Bag Time:    160.082596   Duration: 35.451040 / 35.463741
# Done.

# %%
# %%bash
# rosrun map_server map_saver -f my_map
# Out:
# [ INFO] [1519297835.933727822]: Waiting for the map
# [ INFO] [1519297836.105340462]: Received a 4000 X 4000 map @ 0.050 m/pix
# [ INFO] [1519297836.105422044]: Writing map occupancy data to my_map.pgm
# [ INFO] [1519297836.480208488]: Writing map occupancy data to my_map.yaml
# [ INFO] [1519297836.480434699]: Done

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
% matplotlib inline

# %%
img=mpimg.imread('my_map.pgm')
# Out:
# ValueErrorTraceback (most recent call last)
# <ipython-input-31-8782e8d01781> in <module>()
# ----> 1 img=mpimg.imread('my_map.pgm')
#
# /usr/local/lib/python2.7/dist-packages/matplotlib/image.pyc in imread(fname, format)
#    1304             raise ValueError('Only know how to handle extensions: %s; '
#    1305                              'with Pillow installed matplotlib can handle '
# -> 1306                              'more images' % list(handlers))
#    1307         return im
#    1308
#
# ValueError: Only know how to handle extensions: [u'png']; with Pillow installed matplotlib can handle more images

# %%
img=mpimg.imread('basic_localization_stage_ground_truth.png')

# %%
plt.imshow(img, cmap='gray');
plt.axis('equal');
plt.axis([1250,2500,1600,2600]);
