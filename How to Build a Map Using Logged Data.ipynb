# %%
# %%bash --bg
# roscore
# Out:
# Starting job # 0 in a separate thread.

# %%
# %%bash
# rosparam set use_sim_time true

# %%
# %%bash --bg
# rosrun gmapping slam_gmapping scan:=base_scan
# Out:
# Starting job # 2 in a separate thread.

# %%
# %%bash
# rosbag info basic_localization_stage.bag
# Out:
# path:        basic_localization_stage.bag
# version:     2.0
# duration:    35.5s
# start:       Jan 01 1970 00:02:04.63 (124.63)
# end:         Jan 01 1970 00:02:40.10 (160.10)
# size:        462.6 KB
# messages:    3617
# compression: none [1/1 chunks]
# types:       rosgraph_msgs/Clock   [a9c97c1d230cfc112e270351a944ee47]
#              rosgraph_msgs/Log     [acffd30cd6b6de30f120938c17c593fb]
#              sensor_msgs/LaserScan [90c7ef2dc6895d81024acba2ac42f369]
#              tf/tfMessage          [94810edda583a504dfda3829e70d7eec]
# topics:      /base_scan      24 msgs    : sensor_msgs/LaserScan
#              /clock        3515 msgs    : rosgraph_msgs/Clock
#              /rosout          2 msgs    : rosgraph_msgs/Log
#              /rosout_agg      2 msgs    : rosgraph_msgs/Log
#              /tf             74 msgs    : tf/tfMessage

# %%
# %%bash
# rosbag play --clock basic_localization_stage.bag
# Out:
# [ INFO] [1519298657.660011798]: Opening basic_localization_stage.bag
#
# Waiting 0.2 seconds after advertising topics... done.
#
# Hit space to toggle paused, or 's' to step.
#  [RUNNING]  Bag Time:    160.084707   Duration: 35.453152 / 35.463741
# Done.

# %%
# %%bash
# rosrun map_server map_saver -f my_map
# Out:
# [ INFO] [1519298693.925708871]: Waiting for the map
# [ INFO] [1519298694.190402312]: Received a 4000 X 4000 map @ 0.050 m/pix
# [ INFO] [1519298694.190486802]: Writing map occupancy data to my_map.pgm
# [ INFO] [1519298694.587603665]: Writing map occupancy data to my_map.yaml
# [ INFO] [1519298694.587831066]: Done

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
% matplotlib inline

# %%
img=mpimg.imread('my_map.pgm')

# %%
plt.imshow(img, cmap='gray');
plt.axis('equal');
plt.axis([1250,2500,1600,2600]);

# %%
img=mpimg.imread('basic_localization_stage_ground_truth.png')

# %%
plt.imshow(img, cmap='gray');
plt.axis('equal');
plt.axis([1250,2500,1600,2600]);
